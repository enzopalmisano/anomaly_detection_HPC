# %% [markdown]
# # Examon database connection

# %%
# %matplotlib inline
import os
import re
import numpy as np
import pandas as pd
from datetime import datetime, timedelta 
from examon.examon import Examon, ExamonQL
from itables import show
import itables.options as opt
opt.maxBytes = 0

# %% [markdown]
# #### Examon setup

# %%
KAIROSDB_SERVER = '130.186.13.80'
KAIROSDB_PORT = '3000'
USER = 'Kleto000'
PWD = '6$nhZ764'

ex = Examon(KAIROSDB_SERVER, port=KAIROSDB_PORT, user=USER, password=PWD, verbose=False, proxy=True)
sq = ExamonQL(ex)
# Out:
# <urllib.request.Request object at 0x3ffd1792b6a0>

# %% [markdown]
# ### Node evaluation

# %% [markdown]
# Total metric count:

# %%
def get_metric_count_from_plugin(plugin):
    metrics = sq.DESCRIBE(tag_key = 'plugin', tag_value=plugin).execute()
    return metrics['name'].shape[0]

def get_metric_count_from_plugin_list(plugin_list):
    count = 0
    for plugin in plugin_list:
        count += get_metric_count_from_plugin(plugin)
    return count

metric_count = get_metric_count_from_plugin_list(['ganglia_pub', 'confluent_pub', 'ipmi_pub'])

print("total metric count:",metric_count)
# Out:
# total metric count: 1341

# %%
def extract_features_from_plugin(plugin):
    metrics = sq.DESCRIBE(tag_key = 'plugin', tag_value=plugin).execute()
    return metrics['name'].values

def extract_nodes_from_feature(feature):
    df = sq.DESCRIBE(metric=feature).execute()
    return df.values[3][2]

def get_feature_count_per_node_from_plugin(plugin):
    df = pd.DataFrame(data=None, columns=['node', 'features_count'])
    df = df.set_index('node')
    
    features = extract_features_from_plugin(plugin)
    for feature in features:
        if 'ganglia_pub' == plugin:
            nodes = extract_nodes_from_ganglia_feature(feature)
        else:
            nodes = extract_nodes_from_feature(feature)
        for node in nodes:
            if(node in df.index):
                df['features_count'][node] = df['features_count'][node] + 1
            else:
                df.loc[node] = {"features_count": 1}
    return df

def extract_nodes_from_ganglia_feature(feature):
    df = sq.DESCRIBE(metric=feature).execute()
    raw_nodes = df.iloc[4,2]
    return parse_ganglia_nodes(raw_nodes)

# the format is different w.r.t. the one used for all other plugins
# we need a parsing step
def parse_ganglia_nodes(raw_nodes):
    nodes = []
    regex = re.compile("^((master[0-9]{2})|(r[0-9]{3}c[0-9]{2}s[0-9]{2})|(r[0-9]{3}u[0-9]{2}(l|s)[0-9]{2}))$")  # regular expression corrected
    for raw_node in raw_nodes:
        if '.' in raw_node:
            raw_node = raw_node.split('.')[0]
        if(regex.search(raw_node)):
            nodes.append(raw_node)
    return nodes

# %%
parse_ganglia_nodes(['r183c16s04-hfi','r000u26s04','r000u26s04-hfi'])
# Out:
# ['r000u26s04']

# %% [markdown]
# Printing the features count for each plugin:

# %%
ganglia_count = get_feature_count_per_node_from_plugin('ganglia_pub')

# %%
ganglia_count = ganglia_count.reset_index()
ganglia_nodes = ganglia_count['node']
show(ganglia_nodes, scrollX=True)
# Out:
# <div><table id="4bb5d993-d629-4e0b-a913-3ec2379092d7" class="display"><thead>
#     <tr style="text-align: right;">
#
#       <th>node</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["r000u06l01"], ["r000u26s04"], ["r000u27s05"], ["r000u28s06"], ["r032c01s01"], ["r032c01s02"], ["r032c01s05"], ["r032c01s06"], ["r032c01s09"], ["r032c01s10"], ["r032c02s01"], ["r032c02s02"], ["r032c02s03"], ["r032c02s04"], ["r032c02s05"], ["r032c02s06"], ["r032c02s07"], ["r032c02s08"], ["r032c02s09"], ["r032c02s10"], ["r032c02s11"], ["r032c02s12"], ["r032c03s02"], ["r032c03s03"], ["r032c03s04"], ["r032c03s05"], ["r032c03s06"], ["r032c03s07"], ["r032c03s08"], ["r032c03s09"], ["r032c03s10"], ["r032c03s11"], ["r032c03s12"], ["r033c01s01"], ["r033c01s02"], ["r033c01s03"], ["r033c01s04"], ["r033c01s05"], ["r033c01s06"], ["r033c01s07"], ["r033c01s08"], ["r033c02s01"], ["r033c02s02"], ["r033c02s05"], ["r033c02s06"], ["r033c02s09"], ["r033c02s10"], ["r033c03s01"], ["r033c03s02"], ["r033c03s05"], ["r033c03s06"], ["r033c03s09"], ["r033c03s10"], ["r033c05s01"], ["r033c05s02"], ["r033c05s05"], ["r033c05s06"], ["r033c05s09"], ["r033c05s10"], ["r033c06s01"], ["r033c06s02"], ["r033c06s05"], ["r033c06s06"], ["r033c06s09"], ["r033c06s10"], ["r034c01s01"], ["r034c01s02"], ["r034c01s03"], ["r034c01s04"], ["r034c01s05"], ["r034c01s06"], ["r034c01s07"], ["r034c01s08"], ["r034c01s09"], ["r034c01s10"], ["r034c01s11"], ["r
# %%
show(ganglia_count, scrollX=True)
# Out:
# <div><table id="42984a42-f0d5-467b-80bd-42fc551b09cf" class="display"><thead>
#     <tr style="text-align: right;">
#
#       <th>node</th>
#       <th>features_count</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["r000u06l01", "66"], ["r000u26s04", "33"], ["r000u27s05", "33"], ["r000u28s06", "33"], ["r032c01s01", "33"], ["r032c01s02", "33"], ["r032c01s05", "33"], ["r032c01s06", "33"], ["r032c01s09", "33"], ["r032c01s10", "33"], ["r032c02s01", "33"], ["r032c02s02", "33"], ["r032c02s03", "33"], ["r032c02s04", "33"], ["r032c02s05", "33"], ["r032c02s06", "33"], ["r032c02s07", "33"], ["r032c02s08", "33"], ["r032c02s09", "33"], ["r032c02s10", "33"], ["r032c02s11", "33"], ["r032c02s12", "33"], ["r032c03s02", "33"], ["r032c03s03", "33"], ["r032c03s04", "33"], ["r032c03s05", "33"], ["r032c03s06", "33"], ["r032c03s07", "33"], ["r032c03s08", "33"], ["r032c03s09", "33"], ["r032c03s10", "33"], ["r032c03s11", "33"], ["r032c03s12", "33"], ["r033c01s01", "434"], ["r033c01s
06", "33"], ["r035c02s07", "33"], ["r035c02s08", "33"], ["r035c02s09", "33"], ["r035c02s10", "33"], ["r035c02s11", "33"], ["r035c02s12", "33"], ["r035c03s01", "33"], ["r035c03s02", "33"], ["r035c03s03", "33"], ["r035c03s04", "33"], ["r035c03s05", "33"], ["r035c03s06", "33"], ["r035c03s07", "33"], ["r035c03s08", "33"], ["r035c03s09", "33"], ["r035c03s10", "33"], ["r035c03s11", "33"], ["r035c03s12", "33"], ["r035c04s01", "33"], ["r035c04s02", "33"], ["r035c04s03", "33"], ["r035c04s04", "33"], ["r035c04s05", "33"], ["r035c04s06", "33"], ["r035c0 ...

# %%
ipmi_count = get_feature_count_per_node_from_plugin('ipmi_pub')

# %%
show(ipmi_count, scrollX=True)
# Out:
# <div><table id="7662a805-babe-463b-96c4-ee956dcd4671" class="display"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>features_count</th>
#     </tr>
#     <tr>
#       <th>node</th>
#       <th></th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["node001", "16"], ["node002", "16"], ["node003", "16"], ["node004", "16"], ["node005", "16"], ["node006", "16"], ["node007", "16"], ["node008", "16"], ["node009", "16"], ["node010", "16"], ["node011", "16"], ["node012", "16"], ["node013", "16"], ["node014", "16"], ["node015", "16"], ["node016", "16"], ["node017", "16"], ["node018", "16"], ["node019", "16"], ["node020", "16"], ["node021", "16"], ["node022", "16"], ["node023", "16"], ["node024", "16"], ["node025", "16"], ["node026", "16"], ["node027",
><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>features_count</th>
#     </tr>
#     <tr>
#       <th>node</th>
#       <th></th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["r054u29g01", "60"], ["r032c01s01", "132"], ["r032c01s02", "131"], ["r032c01s05", "127"], ["r032c01s06", "127"], ["r032c01s09", "131"], ["r032c01s10", "127"], ["r032c02s01", "132"], ["r032c02s02", "132"], ["r032c02s03", "132"], ["r032c02s04", "132"], ["r032c02s05", "132"], ["r032c02s06", "132"], ["r032c02s07", "132"], ["r032c02s08", "132"], ["r032c02s09", "132"], ["r032c02s10", "132"], ["r032c02s11", "132"], ["r032c02s12", "132"], ["r032c03s02", "132"], ["r032c03s03", "132"], ["r032c03s04", "132"], ["r032c03s05", "132"], ["r032c03s06", "132"], ["r032c03s07", "132"], ["r032c03s08", "132"], ["r032c03s09", "132"], ["r032c03s10", "132"], ["r032c03s11", "132"], ["r032c03s12", "132"], ["r033c01s01", "129"], ["r033c01s02", "129"], ["r033c01s03", "130"], ["r033c01s04", "129"], ["r033c01s05", "129"], ["r033c01s06", "129"], ["r033c01s07", "129"], ["r033c02s
# %%
ganglia_count = get_feature_count_per_node_from_plugin('ganglia_pub')

# %%
show(ganglia_count, scrollX=True)
# Out:
# <div><table id="2ac67106-0df6-43ed-905c-4abbce30b965" class="display"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>features_count</th>
#     </tr>
#     <tr>
#       <th>node</th>
#       <th></th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["r000u06l01", "66"], ["r000u26s04", "33"], ["r000u27s05", "33"], ["r000u28s06", "33"], ["r032c01s01", "33"], ["r032c01s02", "33"], ["r032c01s05", "33"], ["r032c01s06", "33"], ["r032c01s09", "33"], ["r032c01s10", "33"], ["r032c02s01", "33"], ["r032c02s02", "33"], ["r032c02s03", "33"], ["r032c02s04", "33"], ["r032c02s05", "33"], ["r032c02s06", "33"], ["r032c02s07", "33"], ["r032c02s08", "33"], ["r032c02s09", "33"], ["r032c02s10", "33"], ["r032c02s11", "33"], ["r032c02s12", "33"], ["r032c03s02", "33"], ["r032c03s03", "33"], ["r032c03s04", "33"], ["r032c03s05", "33"], ["r032c03s06", "33"], ["r032c03s07", "33"], ["r032c03s08", "33"],
["r035c02s01", "33"], ["r035c02s02", "33"], ["r035c02s03", "33"], ["r035c02s04", "33"], ["r035c02s05", "33"], ["r035c02s06", "33"], ["r035c02s07", "33"], ["r035c02s08", "33"], ["r035c02s09", "33"], ["r035c02s10", "33"], ["r035c02s11", "33"], ["r035c02s12", "33"], ["r035c03s01", "33"], ["r035c03s02", "33"], ["r035c03s03", "33"], ["r035c03s04", "33"], ["r035c03s05", "33"], ["r035c03s06", "33"], ["r035c03s07", "33"], ["r035c03s08", "33"], ["r035c03s09", "33"], ["r035c03s10", "33"], ["r035c03s11", "33"], ["r035c03s12", "33"], ["r035c04s01", "33"], ["r035c04s02", "33"], ["r035c04s03", "33"], ["r035c04s04", "33"], ["r035c04s05", "33"], ["r035c04s06", "33"], ["r035c0 ...

# %% [markdown]
# I nodi che compaiono qui che hanno più di 999 features (il totale di ganglia) non sono reali, nel senso che derivano da un preprocessing necessario poichè ganglia non salva i nodi nel formato 'r033c02s05' ma per esempio 'r033c02s05.galileo.cineca.it'.
# Estraendo i nodi da ganglia, questi vengono preprocessati per rimuovere il suffisso non necessario (che non permetterebbe il matching con i dati degli altri plugin).
# I nodi con count maggiore derivano dall'unione di più nodi 'reali' che attraverso il preprocessing vengono evidentemente fatti unificare. In ogni caso, nessuno di questi è presente negli altri plugin, quindi possono essere scartati.

# %%
ganglia_count = ganglia_count[ganglia_count['features_count'] <= 999]

# %%
show(ganglia_count, scrollX=True)
# Out:
# <div><table id="3b180274-0e25-4b0b-b59f-c32aee1b9887" class="display"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>features_count</th>
#     </tr>
#     <tr>
#       <th>node</th>
#       <th></th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements
04s11", "33"], ["r034c04s12", "33"], ["r034c05s01", "33"], ["r034c05s02", "33"], ["r034c05s03", "33"], ["r034c05s04", "33"], ["r034c05s05", "33"], ["r034c05s06", "33"], ["r034c05s07", "33"], ["r034c05s08", "33"], ["r034c05s09", "33"], ["r034c05s10", "33"], ["r034c05s11", "33"], ["r034c05s12", "33"], ["r034c06s01", "33"], ["r034c06s02", "33"], ["r034c06s03", "33"], ["r034c06s04", "33"], ["r034c06s05", "33"], ["r034c06s06", "33"], ["r034c06s07", "33"], ["r034c06s08", "33"], ["r034c06s09", "33"], ["r034c06s10", "33"], ["r034c06s11", "33"], ["r034c06s12", "33"], ["r035c01s01", "33"], ["r035c01s02", "33"], ["r035c01s03", "33"], ["r035c01s04", "33"], ["r035c01s05", "33"], ["r035c01s06", "33"], ["r035c01s07", "33"], ["r035c01s08", "33"], ["r035c01s09", "33"], ["r035c01s10", "33"], ["r035c01s11", "33"], ["r035c01s12", "33"], ["r035c02s01", "33"], ["r035c02s02", "33"], ["r035c02s03", "33"], ["r035c02s04", "33"], ["r035c02s05", "33"], ["r035c02s06", "33"], ["r035c02s07", "33"], ["r035c02s08", "33"], ["r035c02s09", "33"], ["r035c02s10", "33"], ["r035c02s11", "33"], ["r035c02s12", "33"], ["r035c03s01", "33"], ["r035c03s02", "33"], ["r035c03s03", "33"], ["r035c03s04", "33"], ["r035c03s05", "33"], ["r035c03s06", "33"], ["r035c03s07", "33"], ["r035c03s08", "33"], ["r035c03s09", "33"], ["r035c03s10", "33"], ["r035c03s11", "33"], ["r035c03s12", "33"], ["r035c04s01", "33"], ["r035c04s02", "33"], ["r035c04s03", "33"], ["r035c04s04", "33"], ["r035c04s05", "33"], ["r035c04s06", "33"], ["r035c0 ...

# %% [markdown]
# (E' necessario scartare anche il nodo 'r064u15x01', poichè non è presente in nagios. In ogni caso verrà filtrato durante il merging)

# %% [markdown]
# Merging all features information:

# %%
ganglia_count = ganglia_count.reset_index()
confluent_count = confluent_count.reset_index()
ipmi_count = ipmi_count.reset_index()

# %%
show(ganglia_count, scrollX=True)
# Out:
# <div><table id="ca5147c0-62da-481a-b8f3-90b2067d6dba" class="display"><thead>
#     <tr style="text-align: right;">
#
#       <th>node</th>
#       <th>features_count</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["r000u06l01", "66"], ["r000u26s04", "33"], ["r000u27s05", "33"], ["r000u28s06", "33"], ["r032c01s01", "33"], ["r032c01s02", "33"], ["r032c01s05", "33"], ["r032c01s06", "33"], ["r032c01s09", "33"], ["r032c01s10", "33"], ["r032c02s01", "33"], ["r032c02s02", "33"], ["r032c02s03", "33"], ["r032c02s04", "33"], ["r032c02s05", "33"], ["r032c02s06", "33"], ["r032c02s07", "33"], ["r032c02s08", "33"], ["r032c02s09", "33"], ["r032c02s10", "33"], ["r032c02s11", "33"], ["r032c02s12", "33"], ["r032c03s02", "33"], ["r032c03s03", "33"], ["r032c03s04", "33"], ["r032c03s05", "33"], ["r032c03s06", "33"], ["r032c03s07", "33"], ["r032c03s08", "33"], ["r032c03s09", "33"], ["r032c03s10", "33"], ["r032c03s11", "33"], ["r032c03s12", "33"], ["r033c01s01", "434"], ["r033c01s02", "434"], ["r033c01s03", "33"], ["r033c01s04", "33"], ["r033c01s05", "33"], ["r033c01s06", "442"], ["r033c01s07", "434"], ["r033c01s08", "33"], ["r033c02s01", "33"], ["r033c02s02", "33"], ["r033c02s05", "442"], ["r033c02s06", "33"], ["r033c02s09", "33"], ["r033c02s10", "33"], ["r033c03s01", "33"], ["r033c03s02", "33"], ["r033c03s05", "33"], ["r033c03s06", "33"], ["r033c03s09", "33"], ["r033c03s10", "33"], ["r033c05s01", "33"], ["r033c05s02", "33"], ["r033c05s05", "33"], ["r033c05s06", "33"], ["r033c05s09", "33"], ["r033c05s10", "33"], ["r033c06s01", "33"], ["r033c06s02", "33"], ["r033c06s05", "33"], ["r033c06s06", "33"], ["r033c06s09", "33"], ["r033c06s10", "33"], ["r034c01s01", "33"], ["r034c01s02", "33"], ["r034c01s03", "33"], ["r034c01s04", "33"], ["r034c01s05", "33"], ["r034c01s06", "33"], ["r034c01s07", "33"], ["r034c01s08", "33"], ["r034c01s09", "33"], ["r034c01s10", "33"], ["r034c01s11", "33"], ["r034c01s12", "33"], ["r034c02s01", "33"], ["r034c02s02", "33"], ["r034c02s03", "33"], ["r034c02s04", "33"], ["r034c02s05", "33"], ["r034c02s06", "33"], ["r034c02s07", "33"], ["r034c02s08", "33"], ["r034c02s09", "33"], ["r034c
>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["r032c01s01", 183.0], ["r032c01s02", 182.0], ["r032c01s05", 178.0], ["r032c01s06", 178.0], ["r032c01s09", 182.0], ["r032c01s10", 178.0], ["r032c02s01", 183.0], ["r032c02s02", 183.0], ["r032c02s03", 183.0], ["r032c02s04", 183.0], ["r032c02s05", 183.0], ["r032c02s06", 183.0], ["r032c02s07", 183.0], ["r032c02s08", 183.0], ["r032c02s09", 183.0], ["r032c02s10", 183.0], ["r032c02s11", 183.0], ["r032c02s12", 183.0], ["r032c03s02", 183.0], ["r032c03s03", 183.0], ["r032c03s04", 183.0], ["r032c03s05", 183.0], ["r032c03s06", 183.0], ["r032c03s07", 183.0], ["r032c03s08", 183.0], ["r032c03s09", 183.0], ["r032c03s10", 183.0], ["r032c03s11", 183.0], ["r032c03s12", 183.0], ["r033c01s01", 581.0], ["r033c01s02", 581.0], ["r033c01s03", 181.0], ["r033c01s04", 180.0], ["r033c01s05", 180.0], ["r033c01s06", 589.0], ["r033c01s07", 581.0], ["r033c01s08", 142.0], ["r033c02s01", 181.0], ["r033c02s02", 181.0], ["r033c02s05", 590.0], ["r033c02s06", 142.0], ["r033c02s09", 142.0], ["r033c02s10", 142.0], ["r033c03s01", 143.0], ["r033c03s02", 143.0], ["r033c03s05", 143.0], ["r033c03s06", 143.0], ["r033c03s09", 143.0], ["r033c03s10", 143.0], ["r033c05s01", 143.0], ["r033c05s02", 143.0], ["r033c05s05", 143.0], ["r033c05s06", 143.0], ["r033c05s09", 143.0], ["r033c05s10", 143.0], ["r033c06s
# %%
ganglia_count = ganglia_count.set_index('node').rename(columns={'features_count':'ganglia'})
ipmi_count = ipmi_count.set_index('node').rename(columns={'features_count':'ipmi'})
confluent_count = confluent_count.set_index('node').rename(columns={'features_count':'confluent'})

# %%
all_data = ganglia_count.join([ipmi_count, confluent_count], how='inner')

# %%
show(all_data, scrollX=True)
# Out:
# <div><table id="0600b810-dc3f-4666-8e9b-f45bac474d8b" class="display"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ganglia</th>
#       <th>ipmi</th>
#       <th>confluent</th>
#       <th>total</th>
#     </tr>
#     <tr>
#       <th>node</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["r032c01s01", "33", "18", "132", 0], ["r032c01s02", "33", "18", "131", 0], ["r032c01s05", "33", "18", "127", 0], ["r032c01s06", "33", "18", "127", 0], ["r032c01s09", "33", "18", "131", 0], ["r032c01s10", "33", "18", "127", 0], ["r032c02s01", "33", "18", "132", 0], ["r032c02s02", "33", "18", "132", 0], ["r032c02s03", "33", "18", "132", 0], ["r032c02s04", "33", "18", "132", 0], ["r032c02s05", "33", "18", "132", 0], ["r032c02s06", "33", "18", "132", 0], ["r032c02s07", "33", "18", "132", 0], ["r032c02s08", "33", "18", "132", 0], ["r032c02s09", "33", "18", "132", 0], ["r032c02s10", "33", "18", "132", 0], ["r032c02s11", "33", "18", "132
r034c03s07", "33", "18", "132", 0], ["r034c03s08", "33", "18", "132", 0], ["r034c03s09", "33", "18", "132", 0], ["r034c03s10", "33", "18", "132", 0], ["r034c03s11", "33", "18", "132", 0], ["r034c03s12", "33", "18", "132", 0], ["r034c04s01", "33", "18", "132", 0], ["r034c04s02", "33", "18", "132", 0], ["r034c04s03", "33", "18", "132", 0], ["r034c04s04", "33", "18", "131", 0], ["r034c04s05", "33", "18", "132", 0], ["r034c04s06", "33", "18", "132", 0], ["r034c04s07", "33", "18", "132", 0], ["r034c04s08", " ...

# %%
all_data.insert(len(all_data.columns), 'total', 0)

# %%
for index in all_data.index:
    all_data.loc[index, 'total'] = all_data.loc[index, 'ganglia'] + \
                                   all_data.loc[index, 'ipmi'] + \
                                   all_data.loc[index, 'confluent']

# %%
show(all_data)
# Out:
# <div><table id="a9717f3a-1de2-44bf-b977-847c7e66420c" class="display"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ganglia</th>
#       <th>ipmi</th>
#       <th>confluent</th>
#       <th>total</th>
#     </tr>
#     <tr>
#       <th>node</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"data": [["r032c01s01", "33", "18", "132", 183], ["r032c01s02", "33", "18", "131", 182], ["r032c01s05", "33", "18", "127", 178], ["r032c01s06", "33", "18", "127", 178], ["r032c01s09", "33", "18", "131", 182], ["r032c01s10", "33", "18", "127", 178], ["r032c02s01", "33", "18", "132", 183], ["r032c02s02", "33", "18", "132", 183], ["r032c02s03", "33", "18", "132", 183], ["
11", "33", "18", "132", 183], ["r034c02s12", "33", "18", "132", 183], ["r034c03s01", "33", "18", "132", 183], ["r034c03s02", "33", "18", "132", 183], ["r034c03s03", "33", "18", "132", 183], ["r034c03s04", "33", "18", "132", 183], ["r034c03s05", "33", "18", "132", 183], ["r034c03s06", "33", "18", "132", 183], ["r034c03s07", "33", "18", "132", 183], ["r034c03s08", "33", "18", "132", 183], ["r034c03s09", "33", "18", "132", 183], ["r034c03s10", "33", "18", "132", 183], ["r034c03s11", "33", "18", "132", 183], ["r034c03s12", "33", "18", "132", 183], ["r034c04s01", "33", "18", "132", 183], ["r034c04s02", "33", "18", "132", 183], ["r034c04s03", "33", "18" ...

# %% [markdown]
# ### Plugin nagios_pub
# Extracting data from nagios_pub when a critical state is matched (state=2):
# <ul>
#     <li>DOWN<sup>(*)</sup>,</li>
#     <li>DOWN<sup>(*)</sup>+DRAIN,</li>
#     <li>IDLE<sup>(*)</sup>+DRAIN,</li>
#     <li>ALLOCATED+DRAIN,</li>
#     <li>MIXED+COMPLETING+DRAIN,</li>
#     <li>or any other combination of them</li>
# </ul>
#
# Considered time: 1h 30m

# %%
opt.classes = ["display", "wrap"]

data = sq.SELECT('node','state') \
         .FROM('plugin_output') \
         .WHERE(plugin='nagios_pub', state='2', node='r183c12s04') \
         .TSTART('1-09-2019 00:00:00') \
         .TSTOP( '15-10-2019 00:00:00') \
         .execute()

# %%
print(data.df_table.shape)
show(data.df_table, scrollX=True)
# Out:
# (928, 5)
# <div><table id="5f0f7bf3-189d-4e21-be10-fb7d2aeb14b0" class="display wrap"><thead>
#     <tr style="text-align: right;">
#
#       <th>timestamp</th>
#       <th>value</th>
#       <th>name</th>
#       <th>node</th>
#       <th>state</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"data": [["2019-09-05 20:45:00.000", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:00:00.009", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:00:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:15:00.020", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:00:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:15:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:30:00.078", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:30:00.002", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:00:00.003", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:45:00.013", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:30:00.074", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:00:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:15:00.009", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:30:00.022", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 06:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 06: ...

# %%
data = data.df_table
values = data[['value']]

# %%
critical_2 = data[data['state'] == '2']
critical_2 = critical_2.reset_index(drop=True)
show(critical_2, scrollX=True)
# Out:
# <div><table id="7609a01e-c78b-4923-aeff-7354b6dd04d4" class="display wrap"><thead>
#     <tr style="text-align: right;">
#
#       <th>timestamp</th>
#       <th>value</th>
#       <th>name</th>
#       <th>node</th>
#       <th>state</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["2019-09-05 20:45:00.000", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:00:00.009", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:00:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:15:00.020", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:00:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:15:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:30:00.078", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:30:00.002", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:00:00.003", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:45:00.013", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:30:00.074", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:00:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:15:00.009", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:30:00.022", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 06:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ...

# %%
show(values.value.unique(), scrollX=True)
# Out:
# <div><table id="3976aba8-01ab-4eeb-b931-9b88b283bdef" class="display wrap"><thead>
#     <tr style="text-align: right;">
#
#       <th>0</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["IDLE+DRAIN matches a critical state"], ["C(/marconi[umount],/marconi_scratch[umount],/marconi_work[umount]) W() O()"], ["C(/marconi_meteo[umount]) W() O()"], ["C({mmgestate=down}[/marconi,/marconi_work]) W() O()"], ["C(/marconi[umount],/marconi_work[umount]) W() O(/marconi_scratch)"], ["ERROR, the command timeouted: /sbin/runuser -c '/cinecalocal/nagios/passive/shsc_all_fss.pl /marconi /marconi_scratch /marconi_work' pronag01"], ["ERROR, this mhsc command did not produce a value for the service: /sbin/runuser -c '/usr/bin/ssh master01 /cinecalocal/nagios/passive/mhsc_nodehealth_a3.pl' root"], ["DOWN+DRAIN matches a critical state"], ["CRITICAL - Socket timeout"], ["CRITICAL - Plugin timed out"], ["DOWN*+DRAIN matches a critical state"], ["ERROR, the command timeouted: /sbin/runuser -c '/usr/bin/ssh master01 /cinecalocal/nagios/passive/mhsc_nodehealth_a3.pl' root"]]};
#         dt_args = eval_functions(dt_args);
#         table = $('#3976aba8-01ab-4eeb-b931-9b88b283bdef').DataTable(dt_args);
#     });
# })
# </script>
# </div>

# %%
criticalities = data[(data['state'] == '2') & ((data['value'].str.contains("DRAIN")) | (data['value'].str.contains("DOWN")))]
criticalities = criticalities.reset_index(drop=True)
show(criticalities, scrollX=True)
# Out:
# <div><table id="fd4682bf-4076-41c2-8322-0dacba407f20" class="display wrap"><thead>
#     <tr style="text-align: right;">
#
#       <th>timestamp</th>
#       <th>value</th>
#       <th>name</th>
#       <th>node</th>
#       <th>state</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         function eval_functions(map_or_text) {
#             if (typeof map_or_text === "string") {
#                 if (map_or_text.startsWith("function")) {
#                     try {
#                         // Note: parenthesis are required around the whole expression for eval to return a value!
#                         // See https://stackoverflow.com/a/7399078/911298.
#                         //
#                         // eval("local_fun = " + map_or_text) would fail because local_fun is not declared
#                         // (using var, let or const would work, but it would only be declared in the local scope
#                         // and therefore the value could not be retrieved).
#                         const func = eval(`(${map_or_text})`);
#                         if (typeof func !== "function") {
#                             // Note: backquotes are super convenient!
#                             // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals
#                             console.error(
#                                 `Evaluated expression "${map_or_text}" is not a function (type is ${typeof func})`
#                             );
#                             return map_or_text;
#                         }
#                         // Return the function
#                         return func;
#                     } catch (e) {
#                         // Make sure to print the error with a second argument to console.error().
#                         console.error(`itables was not able to parse "${map_or_text}"`, e);
#                     }
#                 }
#             } else if (typeof map_or_text === "object") {
#                 if (map_or_text instanceof Array) {
#                     // Note: "var" is now superseded by "let" and "const".
#                     // https://medium.com/javascript-scene/javascript-es6-var-let-or-const-ba58b8dcde75
#                     const result = [];
#                     // Note: "for of" is the best way to iterate through an iterable.
#                     // https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of
#                     for (const item of map_or_text) {
#                         result.push(eval_functions(item));
#                     }
#                     return result;
#
#                     // Alternatively, more functional approach in one line:
#                     // return map_or_text.map(eval_functions);
#                 } else {
#                     const result = {};
#                     // Object.keys() is safer than "for in" because otherwise you might have keys
#                     // that aren't defined in the object itself.
#                     //
#                     // See https://stackoverflow.com/a/684692/911298.
#                     for (const item of Object.keys(map_or_text)) {
#                         result[item] = eval_functions(map_or_text[item]);
#                     }
#                     return result;
#                 }
#             }
#
#             return map_or_text;
#         }
#         var dt_args = {"scrollX": true, "data": [["2019-09-05 20:45:00.000", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:00:00.009", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 21:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:00:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:15:00.020", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 22:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:00:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:15:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:30:00.078", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-05 23:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 00:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:30:00.002", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 01:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:00:00.003", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 02:45:00.013", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:30:00.074", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 03:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:00:00.008", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:15:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:30:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 04:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:15:00.009", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:30:00.022", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 05:45:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ["2019-09-06 06:00:00.100", "IDLE+DRAIN matches a critical state", "plugin_output", "r183c12s04", "2"], ...
